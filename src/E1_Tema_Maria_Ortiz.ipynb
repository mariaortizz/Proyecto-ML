# %% [markdown]
# # Primera entrega ML

# %% [markdown]
# ### Título de proyecto

# %%
# Escribir el título de proyecto en Markdown
titulo = "¿Cuanto cuesta?"

# %% [markdown]
# ## Titulo: ¿Cuanto cuesta?

# %% [markdown]
# ### Tema

# %%
tema = "Después de hacer un analisis de el mercado inmobiliario y obtener las principales variables que afectan al precio de las viviendas en Madrid, se plantea en base a esto hacer un predicción de precios para poder tener una estimación del valor de una vivienda previo a la visita utilizando los datos que tenemos a modo de 'comparables' es decir obtener un precio estimado tomando los datos que tenemos de inmuebles que cumples caracteristicas similares"
# Breve descripción del proyecto

# %% [markdown]
# TEMA: Después de hacer un analisis de el mercado inmobiliario y obtener las principales variables que afectan al precio de venta de las viviendas en Madrid, se plantea en base a esto hacer un predicción del precio de los inmuebles para poder tener una estimación del valor de una vivienda previo a una visita para la tasación real del inmueble o en el caso de viviendas que se van a rehabilitar para la venta tener un estimado de precio para poder ofertar y obtener un margen de ganancia. Esto mejoraría el trabajo previo de cualquiera de los dos procesos mencionados ya que esas estimaciones se hacen mediante comparables con caracteristicas similares, pero el volumen de datos al hacerlo mediante un modelo reduce mucho el margen de error que podemos estimar para cada vivienda.

# %% [markdown]
# ### Datasets y fuentes alternativas de datos
# Incluye aquí una breve descripción del dataset o datasets para tu proyecto. Incluye también las fuentes de cada uno de ellos.

# %%
tipo_ml = "Regresión" # Regresión? Clasificación?
target_descr = "precio_venta_por_m2 - variable continua" # Descripción de la variable objetivo
metricas = ['RMSE', 'R2'] # Metricas escogidas para evaluar los modelos

# %%
# dasets y enlaces de datasets en Markdown
enlaces = ["https://www.kaggle.com/datasets/mirbektoktogaraev/madrid-real-estate-market"] # ["www.paginacondatos.com", "www.paginawebscrapeada.com", "www.unaapi.com"]

# %% [markdown]
# Los datos utilizados se obtuvieros de [Link Dataset](https://www.kaggle.com/datasets/mirbektoktogaraev/madrid-real-estate-market)

# %%
import pandas as pd
df = pd.read_csv('src/data/raw/houses_Madrid.csv', index_col='Unnamed: 0')
df.head()
# Out:
#       id                                              title  \
# 0  21742              Piso en venta en calle de Godella, 64
# 1  21741   Piso en venta en calle de la del Manojo de Rosas
# 2  21740               Piso en venta en calle del Talco, 68
# 3  21739               Piso en venta en calle Pedro Jiménez
# 4  21738  Piso en venta en carretera de Villaverde a Val...
#
#                 subtitle  sq_mt_built  sq_mt_useful  n_rooms  n_bathrooms  \
# 0  San Cristóbal, Madrid         64.0          60.0        2          1.0
# 1    Los Ángeles, Madrid         70.0           NaN        3          1.0
# 2     San Andrés, Madrid         94.0          54.0        2          2.0
# 3     San Andrés, Madrid         64.0           NaN        2          1.0
# 4    Los Rosales, Madrid        108.0          90.0        2          2.0
#
#    n_floors  sq_mt_allotment  latitude  ...  energy_certificate has_parking  \
# 0       NaN              NaN       NaN  ...                   D       False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21742 entries, 0 to 21741
# Data columns (total 57 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            21742 non-null  int64
#  1   title                         21742 non-null  object
#  2   subtitle                      21742 non-null  object
#  3   sq_mt_built                   21616 non-null  float64
#  4   sq_mt_useful                  8228 non-null   float64
#  5   n_rooms                       21742 non-null  int64
#  6   n_bathrooms                   21726 non-null  float64
#  7   n_floors                      1437 non-null   float64
#  8   sq_mt_allotment               1432 non-null   float64
#  9   latitude                      0 non-null      float64
#  10  longitude                     0 non-null      float64
#  11  raw_address                   16277 non-null  object
# ...
